# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## BAR CHART

# %%
rent_df = pd.read_csv('cleaned.csv')

# %%
rent_df.columns
# Out:
# Index(['Unnamed: 0', 'Posted On', 'BHK', 'Rent', 'Size', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact', 'house_floor', 'no_floor'],
#       dtype='object')

# %%
# seaborn - It is working along with matplotlib

sns.barplot(data=rent_df, x ='City', y = 'Rent', hue= 'City')
# Out:
# <Axes: xlabel='City', ylabel='Rent'>

# %%
# Customizing seaborn charts
sns.set_style('darkgrid')
sns.set_palette('husl')

# plotting bar chart
sns.barplot(data=rent_df, x ='City', y = 'Rent')
# Out:
# <Axes: xlabel='City', ylabel='Rent'>

# %%
# Customizing seaborn charts
sns.set_style('darkgrid')
sns.set_palette('husl')

# plotting bar chart
sns.barplot(data=rent_df, x ='City', y = 'Rent', hue= 'Point of Contact') # Mean (Average is the default)
plt.title('BAR CHART OF AVERAGE RENT IN EACH STATE')
# Out:
# Text(0.5, 1.0, 'BAR CHART OF AVERAGE RENT IN EACH STATE')

# %%
# Customizing seaborn charts
sns.set_style('darkgrid')
sns.set_palette('husl')

# plotting bar chart
sns.barplot(data=rent_df, x ='City', y = 'Rent', hue= 'Point of Contact', estimator= 'sum')
# Out:
# <Axes: xlabel='City', ylabel='Rent'>

# %%
# Plotly

px.histogram(data_frame=rent_df, x ='City', y = 'Rent')

# %%
px.bar(data_frame=rent_df, x ='City', y = 'Rent')

# %%
px.histogram(data_frame=rent_df, x ='City', y = 'Rent', color= 'Point of Contact')

# %%
px.histogram(data_frame=rent_df, x ='City', y = 'Rent', color= 'Point of Contact', barmode= 'group')

# %%
px.histogram(data_frame=rent_df, x ='City', y = 'Rent', color= 'Point of Contact', barmode= 'group',
             histfunc= 'avg')

# %%
px.histogram(data_frame=rent_df, x ='City', y = 'Rent', color= 'Point of Contact', barmode= 'group',
             histfunc= 'avg', title= 'BAR CHART OF AVERAGE RENT IN EACH CITY')

# %% [markdown]
# ### SCATTER PLOT

# %%
# USING SAEBORN

sns.scatterplot(data= rent_df, x= 'Size', y= 'Rent')
plt.title('SCATTER PLOT OF SIZE VS RENT')
# Out:
# Text(0.5, 1.0, 'SCATTER PLOT OF SIZE VS RENT')

# %%
sns.scatterplot(data= rent_df, x= 'Size', y= 'Rent', hue= 'Point of Contact')
plt.title('SCATTER PLOT OF SIZE VS RENT')
# Out:
# Text(0.5, 1.0, 'SCATTER PLOT OF SIZE VS RENT')

# %%
# SCATTER PLOT IN PLOTLY

px.scatter(data_frame= rent_df, x= 'Size', y= 'Rent', title= 'SCATTER PLOT OF SIZE AND RENT')

# %%
px.scatter(data_frame= rent_df, x= 'Size', y= 'Rent', color= 'Point of Contact',
            title= 'SCATTER PLOT OF SIZE AND RENT')

# %% [markdown]
# # PIE CHART

# %%
# matplotlib - there is no pie chart in seaborn, that is why we have to go through creating data. 

temp_data = rent_df[['City', 'Rent']].groupby(['City']).sum()
temp_data.reset_index(inplace = True)
plt.pie(data= temp_data, x= 'Rent', labels= 'City')
plt.title('PIE CHART OF RENT BY CITY')
# Out:
# Text(0.5, 1.0, 'PIE CHART OF RENT BY CITY')

# %%
# plotly

px.pie(data_frame= rent_df, values= 'Rent', names= 'City',
       title= 'PIE CHART OF RENT BY CITY')

# %% [markdown]
# ### Histogram

# %%
# Seaborn

sns.histplot(data= rent_df, x= 'Rent')
# Out:
# <Axes: xlabel='Rent', ylabel='Count'>

# %%
sns.histplot(data= rent_df, x= 'Rent', kde= True)
# Out:
# <Axes: xlabel='Rent', ylabel='Count'>

# %%
sns.histplot(data= rent_df[rent_df['Rent'] < 60000], x= 'Rent', kde= True)
# Out:
# <Axes: xlabel='Rent', ylabel='Count'>

# %%
# Plotly

px.histogram(data_frame= rent_df, x= 'Rent')

# %%
px.histogram(data_frame= rent_df[rent_df['Rent'] < 60000], x= 'Rent')

# %% [markdown]
# ### BOXPLOT

# %%
# Seaborn

sns.boxplot(data= rent_df, x= 'Rent')
# Out:
# <Axes: xlabel='Rent'>

# %%
sns.boxplot(data= rent_df[rent_df['Rent'] < 60000], x= 'Rent')
# Out:
# <Axes: xlabel='Rent'>

# %%
# Plotly

px.box(data_frame= rent_df, x= 'Rent')

# %%
px.box(data_frame= rent_df[rent_df['Rent'] < 60000], x= 'Rent')

# %%
px.box(data_frame= rent_df[rent_df['Rent'] < 60000], y= 'Rent')

# %%
sns.boxplot(data= rent_df[rent_df['Rent'] < 60000], y= 'Rent', x= 'City', hue= 'City')
# Out:
# <Axes: xlabel='City', ylabel='Rent'>

# %%
px.box(data_frame= rent_df[rent_df['Rent'] < 60000], y= 'Rent', x= 'City', color= 'City')

# %% [markdown]
# # MULTIPLE PLOTS

# %%
rent_df = pd.read_csv('House_Rent_Dataset.csv')

# %%
# Using fig to customiza chart size

fig = plt.figure(figsize= (20, 10))

sns.countplot(data= rent_df, x= 'City')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
fig = plt.figure(figsize= (20, 10))

sns.countplot(data= rent_df, x= 'City')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
# Multiple plot with fig and axes

sns.set_style('darkgrid')
sns.set_palette('husl')

fig, axes = plt.subplots(2,1, figsize = (20, 10))           # 2 means number of row, 1=no_columns, 20 = width, 10 = height
sns.countplot(data= rent_df, x= 'City', ax= axes[0])               
sns.countplot(data= rent_df, x= 'Point of Contact', ax= axes[1])
# Out:
# <Axes: xlabel='Point of Contact', ylabel='count'>

# %%
sns.set_style('darkgrid')
sns.set_palette('husl')

fig, axes = plt.subplots(1,2, figsize = (20, 10))         
sns.countplot(data= rent_df, x= 'City', ax= axes[0])               
sns.countplot(data= rent_df, x= 'Point of Contact', ax= axes[1])
# Out:
# <Axes: xlabel='Point of Contact', ylabel='count'>

# %%
# Creating title for each of the charts

sns.set_style('darkgrid')
sns.set_palette('husl')

fig, axes = plt.subplots(1,2, figsize = (20, 10)) 
sns.countplot(data= rent_df, x= 'City', ax= axes[0])               
sns.countplot(data= rent_df, x= 'Point of Contact', ax= axes[1])

axes[0].set_title('NO OF LISTING IN EACH COUNTRY')
axes[1].set_title('LISTING IN BY CONTACT PERSON')
# Out:
# Text(0.5, 1.0, 'LISTING IN BY CONTACT PERSON')

# %%
# INCLUDING OVERALL TITLE 

sns.set_style('darkgrid')
sns.set_palette('husl')

fig, axes = plt.subplots(1,2, figsize = (20, 10)) 
sns.countplot(data= rent_df, x= 'City', ax= axes[0])               
sns.countplot(data= rent_df, x= 'Point of Contact', ax= axes[1])

axes[0].set_title('NO OF LISTING IN EACH COUNTRY')
axes[1].set_title('LISTING IN BY CONTACT PERSON')
plt.suptitle('BAR CHART OF CITY AND CONTACT PERSON')
# Out:
# Text(0.5, 0.98, 'BAR CHART OF CITY AND CONTACT PERSON')

# %%
# INCLUDING - RE-LABELLING THE AXES
sns.set_style('dark')
sns.set_palette('husl')

fig, axes = plt.subplots(1,2, figsize = (20, 10)) 
sns.countplot(data= rent_df, x= 'City', ax= axes[0], hue= 'City')               
sns.countplot(data= rent_df, x= 'Point of Contact', ax= axes[1], hue= 'Point of Contact')

axes[0].set_title('NO OF LISTING IN EACH COUNTRY')
axes[1].set_title('LISTING IN BY CONTACT PERSON')
plt.suptitle('BAR CHART OF CITY AND CONTACT PERSON')
axes[0].set_ylabel('No of Listing')
axes[1].set_ylabel('No of Listing')
# Out:
# Text(0, 0.5, 'No of Listing')

# %%
sns.set_style('dark')
sns.set_palette('husl')

fig, axes = plt.subplots(2,2, figsize = (20, 20)) 
sns.barplot(data= rent_df, x= 'City', y= 'Rent', ax= axes[0, 0], hue= 'City')               
sns.scatterplot(data= rent_df, x= 'Size', y= 'Rent', ax= axes[0, 1])
sns.barplot(data= rent_df, x= 'Furnishing Status', y= 'Rent', ax= axes[1, 0])
sns.boxenplot(data= rent_df, x= 'City', y= 'Rent', ax= axes[1, 1], hue= 'City')

plt.suptitle('CHARTS FOR CITY,SIZE AND FURNISHING STATUS AGAINST RENT')
# Out:
# Text(0.5, 0.98, 'CHARTS FOR CITY,SIZE AND FURNISHING STATUS AGAINST RENT')

# %%
sns.set_style('dark')
sns.set_palette('husl')

fig, axes = plt.subplots(2,3, figsize = (20, 20)) 
sns.barplot(data= rent_df, x= 'City', y= 'Rent', ax= axes[0, 0], hue= 'City')               
sns.scatterplot(data= rent_df, x= 'Size', y= 'Rent', ax= axes[0, 1])
sns.barplot(data= rent_df, x= 'Furnishing Status', y= 'Rent', ax= axes[1, 0])
sns.boxenplot(data= rent_df, x= 'City', y= 'Rent', ax= axes[1, 1], hue= 'City')
sns.histplot(data= rent_df[rent_df['Rent'] < 60000], x= 'Rent', ax= axes[0, 2])
sns.violinplot(data= rent_df[rent_df['Rent'] < 60000], x= 'City', y= 'Rent', ax= axes[1, 2], hue= 'City')

plt.suptitle('CHARTS FOR CITY,SIZE AND FURNISHING STATUS AGAINST RENT')
# Out:
# Text(0.5, 0.98, 'CHARTS FOR CITY,SIZE AND FURNISHING STATUS AGAINST RENT')

# %% [markdown]
# ## STATISTICAL ANALYSIS IN PYTHON
#
# 1. CORRELATION
# 2. CHI SQUARE
# 3. ANALYSIS OF VARIANCE
# 4. KRUSKAL H WALLIS

# %%
rent_df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
rent_df[['City', 'Rent']].groupby(by = ['City']).count()
# Out:
#            Rent
# City
# Bangalore   886
# Chennai     891
# Delhi       605
# Hyderabad   868
# Kolkata     524
# Mumbai      972

# %%
rent_df[['City']].count()
# Out:
# City    4746
# dtype: int64

# %%
### Exercise


# Plot a bar chart, scatter chart and box plot of city and bhk

fig, axes = plt.subplots(3,1, figsize=(20,10))

sns.barplot(data= rent_df, x= 'City', y= 'BHK', ax= axes[0], hue= 'City')
sns.scatterplot(data= rent_df, x= 'Size', y= 'Rent', ax= axes[1], hue= 'City')
sns.boxplot(data= rent_df, x= 'City', y= 'BHK', ax= axes[2], hue= 'City')
# Out:
# <Axes: xlabel='City', ylabel='BHK'>

# %% [markdown]
# # LESSON 6
#
# 1. CORRELATION

# %%
rent_df.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
kendell_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('kendall')
pearson_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('pearson')
spearman_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('spearman')

kendell_corrr
pearson_corrr
spearman_corrr
# Out:
#            BHK      Rent      Size
# BHK   1.000000  0.568416  0.755146
# Rent  0.568416  1.000000  0.521420
# Size  0.755146  0.521420  1.000000

# %%
kendell_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('kendall')
pearson_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('pearson')
spearman_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('spearman')

fig, axes = plt.subplots(1,3, figsize = (20,7))

sns.heatmap(data= kendell_corrr, ax= axes[0])
sns.heatmap(data= pearson_corrr, ax= axes[1])
sns.heatmap(data= spearman_corrr, ax= axes[2])

plt.suptitle('CORRELATION MATRIX OF RENT, SIZE AND BHK')

axes[0].set_title('KENDELL-TAU')
axes[1].set_title('PEARSON PRODUCT MOMENT')
axes[2].set_title('SPEARMAN RANK CORRELATION')
# Out:
# Text(0.5, 1.0, 'SPEARMAN RANK CORRELATION')

# %%
kendell_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('kendall')
pearson_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('pearson')
spearman_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('spearman')

fig, axes = plt.subplots(1,3, figsize = (20,7))

sns.heatmap(data= kendell_corrr, ax= axes[0], annot= True)  # annot is used to add values
sns.heatmap(data= pearson_corrr, ax= axes[1], annot= True)
sns.heatmap(data= spearman_corrr, ax= axes[2], annot= True)

plt.suptitle('CORRELATION MATRIX OF RENT, SIZE AND BHK')

axes[0].set_title('KENDELL-TAU')
axes[1].set_title('PEARSON PRODUCT MOMENT')
axes[2].set_title('SPEARMAN RANK CORRELATION')
# Out:
# Text(0.5, 1.0, 'SPEARMAN RANK CORRELATION')

# %%
kendell_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('kendall')
pearson_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('pearson')
spearman_corrr = rent_df[['BHK', 'Rent', 'Size']].corr('spearman')

fig, axes = plt.subplots(1,3, figsize = (20,7))

sns.heatmap(data= kendell_corrr, ax= axes[0], annot= True, cbar= False)  # cbar is used to remove the bar line beside the graph
sns.heatmap(data= pearson_corrr, ax= axes[1], annot= True, cbar= False)
sns.heatmap(data= spearman_corrr, ax= axes[2], annot= True, cbar= False)

plt.suptitle('CORRELATION MATRIX OF RENT, SIZE AND BHK')

axes[0].set_title('KENDELL-TAU')
axes[1].set_title('PEARSON PRODUCT MOMENT')
axes[2].set_title('SPEARMAN RANK CORRELATION')
# Out:
# Text(0.5, 1.0, 'SPEARMAN RANK CORRELATION')

# %% [markdown]
# ### Insight

# %%
# testing for normality --  shapiro wilk/ kolmogrov smirnov

from scipy.stats import shapiro

Ho = 'There is normality'
H1 = 'There is no normality'

stats, p_value = shapiro(rent_df['BHK'].values)

if p_value < 0.05:
    print(f'{H1} in BHK')
else:
    print(f'{Ho} in BHK')


print(p_value)
# Out:
# There is no normality in BHK
# 2.5939392668044715e-55

# %%
Ho = 'There is normality'
H1 = 'There is no normality'

stats, p_value = shapiro(rent_df['Rent'].values)

if p_value < 0.05:
    print(f'{H1} in Rent')
else:
    print(f'{Ho} in Rent')


print(p_value)
# Out:
# There is no normality in Rent
# 1.5367508514945888e-86

# %%
Ho = 'There is normality'
H1 = 'There is no normality'

stats, p_value = shapiro(rent_df['Size'].values)

if p_value < 0.05:
    print(f'{H1} in Size')
else:
    print(f'{Ho} in Size')


print(p_value)
# Out:
# There is no normality in Size
# 5.160149111868557e-56

# %%
from scipy.stats import shapiro

Ho = 'There is normality'
H1 = 'There is no normality'

col_test = {}
col_list = ['BHK', 'Rent', 'Size']
for col in col_list:
    stats, p_value = shapiro(rent_df[col].values)
    stats_list = [stats, p_value]
    col_test.update({col: stats_list})

for i, v in col_test.items():
    if v[1] < 0.05:
        print(f'{H1} in {i} @ p-value = {v[1]}')
    else:
        print(f'{Ho} in {i} @ p-value = {v[1]}')
# Out:
# There is no normality in BHK @ p-value = 2.5939392668044715e-55
# There is no normality in Rent @ p-value = 1.5367508514945888e-86
# There is no normality in Size @ p-value = 5.160149111868557e-56

# %%
# testing the statistical significance of the spearman correlation

from scipy.stats import spearmanr

Ho = 'There is not significant correlation'
H1 = 'There is significant correlation'

bhk_rent = stats, p_value = spearmanr(rent_df['BHK'].values, rent_df['Rent'].values)
size_rent = stats, p_value = spearmanr(rent_df['Size'].values, rent_df['Rent'].values)
Size_bhk = stats, p_value = spearmanr(rent_df['Size'].values, rent_df['BHK'].values)

test_pairs = {
    'BHK vs Rent': bhk_rent,
    'Size vs Rent': size_rent,
    'Size vs BHK': Size_bhk
}

for i, v in test_pairs.items():
    if v[1] < 0.05:
        print(f'{H1} in {i} @ p_value = {v[1]} with coeff = {v[0]}')
    else:
        print(f'{Ho} in {i} @ p_value = {v[1]} with coeff = {v[0]}')
# Out:
# There is significant correlation in BHK vs Rent @ p_value = 0.0 with coeff = 0.568416262119478
# There is significant correlation in Size vs Rent @ p_value = 0.0 with coeff = 0.5214199705306055
# There is significant correlation in Size vs BHK @ p_value = 0.0 with coeff = 0.7551462374419557

# %%
# Analysis of varianca (ANOVA)

from scipy.stats import f_oneway

Ho = 'There is no significant different'
H1 = 'There is significant different'

stats, p_value = f_oneway(rent_df[rent_df['City'] == 'Kolkata']['Size'].values,
                          rent_df[rent_df['City'] == 'Delhi']['Size'].values,
                          rent_df[rent_df['City'] == 'Mumbai']['Size'].values,
                          rent_df[rent_df['City'] == 'Bangalore']['Size'].values,
                          rent_df[rent_df['City'] == 'Chennai']['Size'].values,
                          rent_df[rent_df['City'] == 'Hyderabad']['Size'].values,)



if p_value < 0.05:
    print(f'{H1} between sizes in each city @ p_value = {p_value}')
else:
    print(f'{Ho} between sizes in each city @ p_value = {p_value}')
# Out:
# There is significant different between sizes in each city @ p_value = 2.2649292962915317e-45

# %%
rent_df.shape
# Out:
# (4746, 12)

# %%
rent_df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64
