# %%
import pandas as pd
import numpy as np

# libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# !pip install plotly
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# load the dataset
rent_df = pd.read_csv('House_Rent_Dataset.csv')
rent_df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %% [markdown]
# ## Methods for Data Wrangling in Pandas and Numpy

# %%
# .head method

rent_df = pd.read_csv('House_Rent_Dataset.csv')
rent_df.head() # this will return first 5 rows in default
rent_df.head(3) # will return the first 3
# Out:
#     Posted On  BHK   Rent  Size            Floor   Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2  Super Area
# 1  2022-05-13    2  20000   800       1 out of 3  Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3  Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner

# %%
# .tail method
rent_df.tail() # last 5 by default
rent_df.tail(3) # last 3
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4743  2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner

# %%
# .shape attribute - It returns the dimension of the data
rent_df.shape
# Out:
# (4746, 12)

# %%
# .info method - It returns qualitative characteristcis of the dataset
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
# extracting patterns with .extract method and regex
pattern = r'(.*) out of (.*)'
rent_df[['house_floor', 'no_floor']] = rent_df['Floor'].str.extract(pattern)

rent_df.head(3)
# Out:
#     Posted On  BHK   Rent  Size            Floor   Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2  Super Area
# 1  2022-05-13    2  20000   800       1 out of 3  Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3  Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
#
#    Bathroom Point of Contact house_floor no_floor
# 0         2    Contact Owner      Ground        2
# 1         1    Contact Owner           1        3
# 2         1    Contact Owner           1        3

# %%
# .drop method - to remove coloum from data set

rent_df.drop(columns=['Floor'], inplace= True)

# %%
# .colomns attribute = to return the available columns in the dataset

rent_df.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Area Type', 'Area Locality',
#        'City', 'Furnishing Status', 'Tenant Preferred', 'Bathroom',
#        'Point of Contact', 'house_floor', 'no_floor'],
#       dtype='object')

# %%
# inspect column content with .unique method
rent_df['house_floor'].unique()
# Out:
# array(['Ground', '1', '2', '4', '3', '5', '7', '8', 'Upper Basement',
#        '11', 'Lower Basement', '6', '14', '43', '13', '18', '17', '9',
#        '19', '60', '34', '12', '26', '25', '53', '16', '10', '39', '32',
#        '47', '28', '20', '15', '65', '40', '37', '22', '21', '30', '35',
#        '33', '44', '41', '46', '27', '45', '48', '50', '24', '23', '29',
#        '49', '36', '76', nan], dtype=object)

# %%
# inspecting missing values with .isnull.sum

rent_df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# house_floor          4
# no_floor             4
# dtype: int64

# %%
# handling missing values with dropna or fillna method

rent_df.dropna(inplace=True) # this will permanently delete the missing value
rent_df.head(3)
# Out:
#     Posted On  BHK   Rent  Size   Area Type             Area Locality  \
# 0  2022-05-18    2  10000  1100  Super Area                    Bandel
# 1  2022-05-13    2  20000   800  Super Area  Phool Bagan, Kankurgachi
# 2  2022-05-16    2  17000  1000  Super Area   Salt Lake City Sector 2
#
#       City Furnishing Status  Tenant Preferred  Bathroom Point of Contact  \
# 0  Kolkata       Unfurnished  Bachelors/Family         2    Contact Owner
# 1  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 2  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
#
#   house_floor no_floor
# 0      Ground        2
# 1           1        3
# 2           1        3

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4742 entries, 0 to 4745
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4742 non-null   object
#  1   BHK                4742 non-null   int64
#  2   Rent               4742 non-null   int64
#  3   Size               4742 non-null   int64
#  4   Area Type          4742 non-null   object
#  5   Area Locality      4742 non-null   object
#  6   City               4742 non-null   object
#  7   Furnishing Status  4742 non-null   object
#  8   Tenant Preferred   4742 non-null   object
#  9   Bathroom           4742 non-null   int64
#  10  Point of Contact   4742 non-null   object
#  11  house_floor        4742 non-null   object
#  12  no_floor           4742 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 518.7+ KB

# %%
# .reset_index

rent_df.reset_index(drop= True, inplace= True)

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4742 entries, 0 to 4741
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4742 non-null   object
#  1   BHK                4742 non-null   int64
#  2   Rent               4742 non-null   int64
#  3   Size               4742 non-null   int64
#  4   Area Type          4742 non-null   object
#  5   Area Locality      4742 non-null   object
#  6   City               4742 non-null   object
#  7   Furnishing Status  4742 non-null   object
#  8   Tenant Preferred   4742 non-null   object
#  9   Bathroom           4742 non-null   int64
#  10  Point of Contact   4742 non-null   object
#  11  house_floor        4742 non-null   object
#  12  no_floor           4742 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 481.7+ KB

# %%
# SCIPY, StatsModel, SKlearn, Yellowbrick 

# !pip install scipy
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### DATA VISUALIZATION -- LESSON 4

# %%
# This ruturns the already cleaned data and will create the data separately in the directory
rent_df.to_csv('cleaned.csv')
