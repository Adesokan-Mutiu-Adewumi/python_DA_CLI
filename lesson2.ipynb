# %%
# Write a function that accepts 2 numbers and returns the square of the sum of both numbers

def square_sum(x, y):
    sum_num = x + y
    return sum_num ** 2
square_sum(4, 5)
# Out:
# 81

# %% [markdown]
# #### Lamda function worked for FILTER, MAP and REDUCE

# %%
square_sum2 = lambda x,y:(x+y)**2 

print(square_sum2(4,5))
# Out:
# 81

# %% [markdown]
# ### DATA WRANGLING WITH PANDA AND NUMPY

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### CREATING DATAFRAME IN PANDAS
# * FROM SCRATCH
#   1. LIST OF LISTS
#   2. DICTIONARIES
# * LOAD A LOCAL FILE
# * CONNECTING TO DATABASE
# * CONNECT TO API

# %%
# LIST OF LISTS

states = [
    ['Lagos', 'Ikeja', 32, 345600],
    ['Kwara', 'Ilorin', 16, 223000],
    ['Osun', 'Osogbo', 27, 563530],
    ['Kano', 'Kano', 44, 435356]
]

column_name = ['States', 'Capital', 'Lga', 'Population']
data = pd.DataFrame(data = states, columns = column_name)

data
# Out:
#   States Capital  Lga  Population
# 0  Lagos   Ikeja   32      345600
# 1  Kwara  Ilorin   16      223000
# 2   Osun  Osogbo   27      563530
# 3   Kano    Kano   44      435356

# %%
# Dictioneries

clubs = {
    'name': ['Chelsea', 'Man City', 'Arsenal', 'Liverpool', 'Bayer Leverkusen'],
    'Best Player': ['Palmer', 'Debruyne', 'Saka', 'Endo', 'Boniface'],
    'Coach': ['Poch', 'Pep', 'Mikel', 'Klopp', 'Xabi'],
    'UCL': [2, 1, 0.000, 6, 0]
}

club_df = pd.DataFrame(data=clubs)
club_df
# Out:
#                name Best Player  Coach  UCL
# 0           Chelsea      Palmer   Poch  2.0
# 1          Man City    Debruyne    Pep  1.0
# 2           Arsenal        Saka  Mikel  0.0
# 3         Liverpool        Endo  Klopp  6.0
# 4  Bayer Leverkusen    Boniface   Xabi  0.0

# %%
# Loading Local Files

data = pd.read_excel("Trauma Data (Abuja).xlsx")

# %%
data
# Out:
#       SN Hospital Number  Age (years)     Sex        DOA  \
# 0      1             NaN         45.0    Male 2023-06-03
# 1      2             NaN         20.0  Female 2023-06-03
# 2      3             NaN          NaN  Female 2023-06-03
# 3      4             NaN         48.0    Male 2023-06-06
# 4      5             NaN         43.0  Female 2023-06-06
# ..   ...             ...          ...     ...        ...
# 851  852        01472264         21.0    Male 2023-12-30
# 852  853             NaN         75.0    Male 2023-12-30
# 853  854        01472254         65.0  Female 2023-12-30
# 854  855             NaN         36.0    Male 2023-12-30
# 855  856             NaN          8.0    Male 2023-12-31
#
#                                          Brief History  \
# 0    Trauma: Walked in on account of nasal lacerati...
# 1    Trauma: Came in on account of severe abdominal...
# 2    She came in on account of injury to the latera...
# ...

# %%
import mysql.connector
from mysql.connector import Error

# %%
def connect_db(host_name, user_name, db_name, password):
    connection = None
    try:
        connection = mysql.connector.connect(
            host = host_name,
            user = user_name,
            database = db_name,
            passwd = password
        )
    except Error as err:
        print(f'Error: {err}')
    return connection

# Define a read query function

def read_query(connection, query):
    result = None
    cursor = connection.cursor()

    try:
        cursor.execute(query)
        result = cursor.fetchall()
    except Error as err:
        print(f'Error: {err}')
    return result

# %%
connection = connect_db(host_name='localhost', user_name='root',
                        db_name='northwind', password='1234')

query1 = '''

select orderid, freight, shipcountry
from orders
limit 100;

'''

data = read_query(connection=connection, query=query1)

data
# Out:
# [(10248, Decimal('32.3800'), 'France'),
#  (10249, Decimal('11.6100'), 'Germany'),
#  (10250, Decimal('65.8300'), 'Brazil'),
#  (10251, Decimal('41.3400'), 'France'),
#  (10252, Decimal('51.3000'), 'Belgium'),
#  (10253, Decimal('58.1700'), 'Brazil'),
#  (10254, Decimal('22.9800'), 'Switzerland'),
#  (10255, Decimal('148.3300'), 'Switzerland'),
#  (10256, Decimal('13.9700'), 'Brazil'),
#  (10257, Decimal('81.9100'), 'Venezuela'),
#  (10258, Decimal('140.5100'), 'Austria'),
#  (10259, Decimal('3.2500'), 'Mexico'),
#  (10260, Decimal('55.0900'), 'Germany'),
#  (10261, Decimal('3.0500'), 'Brazil'),
#  (10262, Decimal('48.2900'), 'USA'),
#  (10263, Decimal('146.0600'), 'Austria'),
#  (10264, Decimal('3.6700'), 'Sweden'),
#  (10265, Decimal('55.2800'), 'France'),
#  (10266, Decimal('25.7300'), 'Finland'),
#  (10267, Decimal('208.5800'), 'Germany'),
#  (10268, Decimal('66.2900'), 'Venezuela'),
#  (10269, Decimal('4.5600'), 'USA'),
#  (10270, Decimal('136.5400'), 'Finland'),
# ...

# %%
# convert to spreadsheet

data_list = []
for row in data:
    row = list(row)
    data_list.append(row)

orders_df = pd.DataFrame(data = data_list, columns=['Orderid', 'Freight', 'Country'])

orders_df
# Out:
#     Orderid   Freight  Country
# 0     10248   32.3800   France
# 1     10249   11.6100  Germany
# 2     10250   65.8300   Brazil
# 3     10251   41.3400   France
# 4     10252   51.3000  Belgium
# ..      ...       ...      ...
# 95    10343  110.3700  Germany
# 96    10344   23.2900      USA
# 97    10345  249.0600  Germany
# 98    10346  142.0800      USA
# 99    10347    3.1000   Brazil
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Assignment

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Ass 1. Create a dataframe of name, gender, salay, age and population use list of lists approach and dictionery approach

# %%
# List of Lists

demography = [
    ['Muitu', 'Male', 100000, 20, 150000], 
    ['Temi', 'Female', 50000, 15, 120000],
    ['Niyi', 'Male', 200000, 25, 155000],
    ['Maya', 'Female', 300000, 30, 160000]
]

variable_name = ['Name', 'Gender', 'Salary', 'Age', 'Population']

data = pd.DataFrame(data = demography, columns = variable_name)

data
# Out:
#     Name  Gender  Salary  Age  Population
# 0  Muitu    Male  100000   20      150000
# 1   Temi  Female   50000   15      120000
# 2   Niyi    Male  200000   25      155000
# 3   Maya  Female  300000   30      160000

# %%
# Dictionery

demography = {
    'Name': ['Mutiu', 'Temi', 'Niyi', 'Maya'],
    'Gender': ['Male', 'Female', 'Male', 'Female'],
    'Salary': [100000, 50000, 200000, 300000],
    'Age': [20, 15, 25, 30],
    'Population': [150000, 120000, 155000, 160000]
}

data = pd.DataFrame(data = demography)

data
# Out:
#     Name  Gender  Salary  Age  Population
# 0  Mutiu    Male  100000   20      150000
# 1   Temi  Female   50000   15      120000
# 2   Niyi    Male  200000   25      155000
# 3   Maya  Female  300000   30      160000

# %% [markdown]
# #### Ass. 2. Go to KAGGLE.COM/Datasets and download any 2 data set of your choice. and load them into python.

# %%
netflix = pd.read_csv('netflix_titles.csv')

netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
student_spending = pd.read_csv("student_spending (1).csv")
student_spending
# Out:
#      Unnamed: 0  age      gender year_in_school             major  \
# 0             0   19  Non-binary       Freshman        Psychology
# 1             1   24      Female         Junior         Economics
# 2             2   24  Non-binary         Junior         Economics
# 3             3   23      Female         Senior  Computer Science
# 4             4   20      Female         Senior  Computer Science
# ..          ...  ...         ...            ...               ...
# 995         995   22      Female         Senior           Biology
# 996         996   19      Female         Senior           Biology
# 997         997   20        Male         Junior         Economics
# 998         998   22  Non-binary         Senior         Economics
# 999         999   24  Non-binary      Sophomore  Computer Science
#
#      monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0               958            270     5939      709   296             123
# ...

# %%
top_hiphop_artist = pd.read_csv('top_hiphop_artists_tracks.csv')

top_hiphop_artist
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...
